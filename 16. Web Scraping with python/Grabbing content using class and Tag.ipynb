# %% [markdown]
# ### Introduction
#
# When working with web scraping, extracting content efficiently from an HTML document is crucial. BeautifulSoup, a Python library, provides various CSS selectors to locate and retrieve HTML elements using tags, IDs, and classes.

# %% [markdown]
# <table>
#   <tr>
#     <th>CSS Selector</th>
#     <th>Description</th>
#     <th>Example Pattern Code</th>
#     <th>Example Match</th>
#   </tr>
#
#   <tr>
#     <td><span>soup.select('tag')</span></td>
#     <td>Selects all elements with the specified tag (e.g., p, h1, div).</td>
#     <td>soup.select('p')</td>
#     <td>&lt;p&gt;Hello World&lt;/p&gt;</td>
#   </tr>
#
#   <tr>
#     <td><span>soup.select('#id')</span></td>
#     <td>Selects elements by their ID using the # symbol.</td>
#     <td>soup.select('#header')</td>
#     <td>&lt;div id="header"&gt;Header Content&lt;/div&gt;</td>
#   </tr>
#
#   <tr>
#     <td><span>soup.select('.class')</span></td>
#     <td>Selects elements by their class using the . symbol.</td>
#     <td>soup.select('.button')</td>
#     <td>&lt;button class="button"&gt;Click Me&lt;/button&gt;</td>
#   </tr>
#
#   <tr>
#     <td><span>soup.select('div span')</span></td>
#     <td>Selects all &lt;span&gt; elements inside &lt;div&gt; elements.</td>
#     <td>soup.select('div span')</td>
#     <td>&lt;div&gt;&lt;span&gt;Text&lt;/span&gt;&lt;/div&gt;</td>
#   </tr>
#
#   <tr>
#     <td><span>soup.select('div > span')</span></td>
#     <td>Selects only &lt;span&gt; elements that are direct children of &lt;div&gt;.</td>
#     <td>soup.select('div > span')</td>
#     <td>&lt;div&gt;&lt;span&gt;Direct Text&lt;/span&gt;&lt;/div&gt;</td>
#   </tr>
# </table>

# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL of the website to scrape
url = "https://www.biography.com/"
response = requests.get(url)

# Parsing the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, "html.parser")

# Extracting titles using a specific class
# Replace ".css-389x1x" with the actual class name of the title elements
titles = soup.select(".css-389x1x")
for entry in titles:
    print(entry.text.strip())
# Out:
# Inside Dolly Parton’s Private Marriage to Carl Dean
# Inside Ruby Franke’s Chilling Spiral from Popular “Momfluencer” to Convicted Felon

# %%
## Extracting all links (anchor tags)

# %%
links = soup.select("a")
for link in links:
    text = link.get_text(strip=True)
    href = link.get("href", "#")  # Use '#' if href is missing
    print(f"Link to '{text}' ===> https://www.biography.com{href}")
# Out:
# link to 'Search' ===> https://www.biography.com//search
# link to 'Women’s History Month' ===> https://www.biography.com//womens-history
# link to 'History & Culture' ===> https://www.biography.com//history-culture
# link to 'Movies & TV' ===> https://www.biography.com//movies-tv
# link to 'Musicians' ===> https://www.biography.com//musicians
# link to 'Athletes' ===> https://www.biography.com//athletes
# link to 'Artists' ===> https://www.biography.com//artists
# link to 'Power & Politics' ===> https://www.biography.com//political-figures
# link to 'Business' ===> https://www.biography.com//business-leaders
# link to 'Scholars & Educators' ===> https://www.biography.com//scholars-educators
# link to 'Scientists' ===> https://www.biography.com//scientists
# link to 'Activists' ===> https://www.biography.com//activists
# link to 'Notorious Figures' ===> https://www.biography.com//crime
# link to 'BIO Buys' ===> https://www.biography.com//bio-buys
# link to 'Newsletter' ===> https://www.biography.com//email/biography-newsletter
# link to 'Privacy Notice' ===> https://www.biography.com/https://www.hearst.com/-/us-magazines-privacy-notice
# link to 'Terms Of Use' ===> https://www.biography.com/https://www.hearst.com/-/us-magazines-terms-of-use
# link to 'Skip to Content' ===> https://www.biography.com/#main-content
# link to '' ===> https://www.biography.com//
# link to 'Women’s History Month' ===> https://www.biography.com//womens-history
# link to 'Musicians' ===> https://www.biography.com//musicians
# link to 'Movies & TV' ===> https://www.biography.com//movies-tv
# link to 'History & Culture' ===> https://www.biography.com//history-culture
# link to 'Newsletter' ===> https://www.biography.com//email/biography-newsletter
# link to 'Inside Dolly Parton’s Private Marriage to Carl DeanThe country superstar is mourning the death of her husband, who she was married to more than 58 years.By Sara Kettler' ===> https://www.biography.com//musicians/dolly-parton-carl-dean-marriage-relationship-secretive
# link to '51 Famous Women in History Who Have Changed the WorldFrom outer space to the Oscars stage, these trailblazers have left their mark.By Janaya Wecker and Catherine Caruso' ===> https://www.biography.com//history-culture/g43336252/famous-women-in-history
# link to 'Why Meghan Markle Loves the Last Name “Sussex”By Emily Burack' ===> https://www.biography.com//royalty/a64053072/why-meghan-markle-loves-sussex-last-name
# link to 'How Likely Is the Menendez Brothers’ Release?By Tyler Piccotti' ===> https://www.biography.com//crime/a63941332/menendez-brothers-prison-release-paths
# link to 'Here’s the Deal With Alex Cooper and Alix EarleBy Mehera  Bonner' ===> https://www.biography.com//celebrities/a63936459/alex-cooper-alix-earle-drama
# link to 'The 2025 Oscar Winners Who Made HistoryBy Tyler Piccotti' ===> https://www.biography.com//movies-tv/a64016438/2025-oscars-winners-who-made-history
# link to 'Dolly Parton' ===> https://www.biography.com//musicians/dolly-parton
# link to 'Zoe Saldaña' ===> https://www.biography.com//actors/zoe-saldana
# link to 'Conan O’Brien' ===> https://www.biography.com//movies-tv/conan-obrien
# link to 'Lisa' ===> https://www.biography.com//musicians/a63785719/lisa
# link to 'Notorious Figures and Acts' ===> https://www.biography.com/https://www.biography.com/crime
# link to 'Inside Ruby Franke’s Chilling Spiral from Popular “Momfluencer” to Convicted FelonA new Hulu docuseries delves into her crimes through interviews with her estranged husband and children.By Tyler Piccotti' ===> https://www.biography.com//crime/a60319774/ruby-franke-story
# link to 'Where Are Ruby Franke’s Kids and Estranged Husband' ===> https://www.biography.com//crime/a63361153/ruby-franke-kids-and-husband-now
# link to 'Where Is Ruby Franke Now?' ===> https://www.biography.com//crime/a63871505/ruby-franke-now
# link to 'Meet Jodi Hildebrandt, Ruby Franke’s Accomplice' ===> https://www.biography.com//crime/a63963849/who-is-jodi-hildebrandt
# link to 'The Murder of Gabby Petito' ===> https://www.biography.com//crime/a63774730/gabby-petito-death-documentary-true-story
# link to 'Where Is Convicted Scammer Amanda Riley Today?' ===> https://www.biography.com//crime/a63577707/scamanda-amanda-riley-now
# link to 'Why the Menendez Brothers Killed Their Parents' ===> https://www.biography.com//crime/menendez-brothers-murder-case-facts
# link to 'The Story of Gypsy-Rose Blanchard and Her Mother' ===> https://www.biography.com//crime/gypsy-rose-blanchard-mother-dee-dee-murder
# link to '15 Notorious Serial Killers in History' ===> https://www.biography.com//crime/g60732709/famous-serial-killers
# link to 'Culture' ===> https://www.biography.com/https://www.biography.com/history-culture
# link to 'How Did Mikey Madison Get Famous?By Michael Natale' ===> https://www.biography.com//actors/a63918152/how-did-mikey-madison-get-famous
# link to 'See Goldie and Kurt Walk the Oscars Red Carpet By Michelle Manetti' ===> https://www.biography.com//actors/a64016758/goldie-hawn-kurt-russell-oscars-2025
# link to 'How to Buy Sabrina Carpenter TicketsBy Josiah Soto' ===> https://www.biography.com//bio-buys/a63960967/how-to-get-sabrina-carpenter-tour-tickets-2025
# link to 'How to Buy BLACKPINK Tour Tickets in 2025By Josiah Soto' ===> https://www.biography.com//bio-buys/a63942699/how-to-get-blackpink-tour-tickets-2025
# link to 'Susie Wiles Joins the Historic Group of Groundbreaking Women in American PoliticsThe 67-year-old is the first female White House chief of staff.By Catherine Caruso' ===> https://www.biography.com//political-figures/g63434536/historic-female-politicians
# link to '11 Famous Black Inventors Who Changed Your LifeBy Adrienne Donica and Brad Witter' ===> https://www.biography.com//inventors/g46697619/famous-black-inventors
# link to '11 Notable Artists from the Harlem RenaissanceBy Tyler Piccotti' ===> https://www.biography.com//history-culture/g45337922/harlem-reniassance-artists
# link to '10 Famous Explorers Who Connected the WorldBy Caroline Redmond' ===> https://www.biography.com//history-culture/famous-explorers
# link to '22 Famous Scientists You Should KnowBy Tyler Piccotti' ===> https://www.biography.com//scientists/g45099921/famous-scientists
# link to 'How Alec and Hilaria Baldwin Met and Fell In Love' ===> https://www.biography.com//actors/a63866684/alec-baldwin-wife-hilaria-baldwin
# link to 'President Donald Trump’s Family Tree' ===> https://www.biography.com//history-culture/g63740495/family-of-donald-trump
# link to '12 Notable Members of the Kennedy Family' ===> https://www.biography.com//political-figures/g63603234/kennedy-family-tree
# link to 'Elvis Presley’s Family Tree' ===> https://www.biography.com//musicians/a43739007/elvis-presley-family-tree
# link to 'Musicians' ===> https://www.biography.com/https://www.biography.com/musicians
# link to 'See Dolly Parton’s Iconic Oscars Performance' ===> https://www.biography.com//musicians/a64017694/dolly-partons-oscars-performance
# link to '2025 Grammy Nominations in the Major Categories' ===> https://www.biography.com//musicians/a63575627/2025-grammy-nominations-winners
# link to 'The History of “All I Want for Christmas Is You”' ===> https://www.biography.com//musicians/a45721955/mariah-carey-all-i-want-for-christmas-is-you-history
# link to 'All the 2024 CMA Award Winners and Nominees' ===> https://www.biography.com//musicians/a62114937/2024-cma-nominees-winners
# link to 'BIO Buys' ===> https://www.biography.com/https://www.biography.com/bio-buys
# link to 'Recreate Mikey Madison’s Oscars-Night Glam' ===> https://www.biography.com//bio-buys/a64038749/mikey-madison-oscars-beauty-march-2025
# link to 'The White Lotus Actresses Wore This Mascara On Set' ===> https://www.biography.com//bio-buys/a63974854/the-white-lotus-make-beauty-mascara-march-2025
# link to 'How to Put Together an Oscar Watch Party' ===> https://www.biography.com//bio-buys/a63917409/oscar-watch-party-guide
# link to 'Shop Dupes of Parker Posey’s “White Lotus” Dress' ===> https://www.biography.com//bio-buys/a63842375/parker-posey-the-white-lotus-dress-february-2025
# link to 'Robert Pattinson' ===> https://www.biography.com//actors/robert-pattinson
# link to 'How Alexander Graham Bell Helped Helen Keller' ===> https://www.biography.com//inventors/alexander-graham-bell-and-helen-keller
# link to 'Recreate Mikey Madison’s Oscars-Night Glam' ===> https://www.biography.com//bio-buys/a64038749/mikey-madison-oscars-beauty-march-2025
# link to 'All About Kieran Culkin & Jazz Charton’s Marriage' ===> https://www.biography.com//actors/a64015955/kieran-culkin-wife-jazz-charton-marriage-kids
# link to 'See Dolly Parton’s Iconic Oscars Performance' ===> https://www.biography.com//musicians/a64017694/dolly-partons-oscars-performance
# link to 'The White Lotus Actresses Wore This Mascara On Set' ===> https://www.biography.com//bio-buys/a63974854/the-white-lotus-make-beauty-mascara-march-2025
# link to 'Gene Hackman' ===> https://www.biography.com//actors/gene-hackman
# link to 'How to Put Together an Oscar Watch Party' ===> https://www.biography.com//bio-buys/a63917409/oscar-watch-party-guide
# link to 'Your 101 on the Cast of ‘The White Lotus’ Season 3' ===> https://www.biography.com//actors/g63937789/the-white-lotus-season-3-cast
# link to 'Meet Actor Arnold Schwarzenegger’s 5 Children' ===> https://www.biography.com//actors/a63936442/arnold-schwarzenegger-kids
# link to 'Gilda Radner and Gene Wilder's Enduring Love Story' ===> https://www.biography.com//celebrities/a63938628/gilda-radner-gene-wilder-relationship-timeline
# link to 'Lewis Hamilton' ===> https://www.biography.com//athletes/a63906099/lewis-hamilton
# link to '' ===> https://www.biography.com//
# link to '' ===> https://www.biography.com/https://x.com/biography
# link to '' ===> https://www.biography.com/https://www.facebook.com/Biography
# link to '' ===> https://www.biography.com/https://www.instagram.com/biography/
# link to 'About Biography.com' ===> https://www.biography.com//about/a43602329/about-us
# link to 'Newsletter' ===> https://www.biography.com//email/biography-newsletter
# link to 'Contact Us' ===> https://www.biography.com//about/a42731733/contact-us
# link to 'Other Hearst Subscriptions' ===> https://www.biography.com/http://subscribe.hearstmags.com/circulation/shared/index.html
# link to 'Privacy Notice' ===> https://www.biography.com/https://www.hearst.com/-/us-magazines-privacy-notice
# link to 'Terms of Use' ===> https://www.biography.com/https://www.hearst.com/-/us-magazines-terms-of-use
# link to 'CA Notice at Collection' ===> https://www.biography.com/https://www.hearst.com/-/us-magazines-privacy-notice#_ADDITIONAL_INFO
# link to 'DAA Industry Opt Out' ===> https://www.biography.com/https://www.hearst.com/-/us-magazines-privacy-notice#_OPT_OUTS
# link to 'Your CA Privacy Rights/Shine the Light' ===> https://www.biography.com/https://www.hearst.com/-/us-magazines-privacy-notice#_ADDITIONAL_INFO
# link to 'Cookies Choices' ===> https://www.biography.com/#

# %% [markdown]
# ### Explanation:
#
# #### Fetching the Webpage:
#
#     - requests.get(url): Retrieves the webpage content from the provided URL.
#
#     - response.text: Contains the raw HTML data.
#
# #### Parsing HTML with BeautifulSoup:
#
#     - soup = BeautifulSoup(response.text, "html.parser"): Converts the HTML content into a BeautifulSoup object for easy manipulation.
#
# #### Extracting Titles Using a Class Selector:
#
#     - soup.select(".css-389x1x"): Selects elements with the class css-389x1x, which is assumed to be a class used for article titles.
#
#     - entry.text.strip(): Extracts the text and removes unnecessary whitespace.
#
# #### Extracting Links Using a Tag Selector:
#
#     - soup.select("a"): Selects all <a> (anchor) elements.
#
#     - link.get_text(strip=True): Extracts the link text.
#
#     - link.get("href", "#"): Retrieves the href attribute value; if missing, it defaults to #.
#
#     - The output prints each link with its corresponding text and a full URL.
